# %% [markdown]
# <a href="https://colab.research.google.com/github/charleslin2003-prog/my-ml-project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ── Colab 環境初始化 ──
from google.colab import userdata
import os

GH_TOKEN = userdata.get('GH_TOKEN')
GH_USER  = "charleslin2003-prog"
REPO     = "my-ml-project"

# clone(若已存在則進資料夾拉最新)
if not os.path.exists(f"/content/{REPO}"):
    # !git clone https://{GH_TOKEN}@github.com/{GH_USER}/{REPO}.git
# %cd /content/{REPO}
# !git pull

# 設定 git 身分
# !git config user.name "Charles Lin"
# !git config user.email "charleslin2003@gmail.com"

# 安裝套件
# !pip install -q -r requirements.txt

print("✅ 環境就緒")
# Out:
# /content/my-ml-project
# Already up to date.
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/C:/b/abs_173nadx2ha/croot/aext-assistant_1752069955059/work'
#
# ✅ 環境就緒

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
print(torch.cuda.is_available())   # True 才有吃到 GPU
# Out:
# False
